# %% [markdown]
# ## Imports

# %%
import mne

import matplotlib.pyplot as plt

# %% [markdown]
# ## Load subject sample data

# %%
file = "data/S001/S001R06.edf"
data = mne.io.read_raw_edf(file)
raw_data = data.get_data()

info = data.info
channels = data.ch_names
annotations = data.annotations
# Out:
# Extracting EDF parameters from /home/ubuntu/personal-vm/EEG/data/S001/S001R06.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...

# %% [markdown]
# ## Example channel time series visualization

# %%
plt.plot(raw_data[0])

# %%
info
# Out:
# <Info | 7 non-empty values
#  bads: []
#  ch_names: Fc5., Fc3., Fc1., Fcz., Fc2., Fc4., Fc6., C5.., C3.., C1.., ...
#  chs: 64 EEG
#  custom_ref_applied: False
#  highpass: 0.0 Hz
#  lowpass: 80.0 Hz
#  meas_date: 2009-08-12 16:15:00 UTC
#  nchan: 64
#  projs: []
#  sfreq: 160.0 Hz
# >

# %%
channels[0]
# Out:
# 'Fc5.'

# %% [markdown]
# ## Events -> slice full waveform

# %%
events = mne.events_from_annotations(data)
events
# Out:
# Used Annotations descriptions: ['T0', 'T1', 'T2']
# (array([[    0,     0,     1],
#         [  672,     0,     3],
#         [ 1328,     0,     1],
#         [ 2000,     0,     2],
#         [ 2656,     0,     1],
#         [ 3328,     0,     2],
#         [ 3984,     0,     1],
#         [ 4656,     0,     3],
#         [ 5312,     0,     1],
#         [ 5984,     0,     2],
#         [ 6640,     0,     1],
#         [ 7312,     0,     3],
#         [ 7968,     0,     1],
#         [ 8640,     0,     3],
#         [ 9296,     0,     1],
#         [ 9968,     0,     2],
#         [10624,     0,     1],
#         [11296,     0,     2],
#         [11952,     0,     1],
#         [12624,     0,     3],
#         [13280,     0,     1],
#         [13952,     0,     3],
#         [14608,     0,     1],
#         [15280,     0,     2],
#         [15936,     0,     1],
#         [16608,     0,     2],
#         [17264,     0,     1],
#         [17936,     0,     3],
#         [18592,     0,     1],
#         [19264,     0,     3]]),
#  {'T0': 1, 'T1': 2, 'T2': 3})
